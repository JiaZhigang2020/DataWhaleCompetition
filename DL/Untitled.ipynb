# %%
import pandas as pd

# %%
data_df = pd.read_excel('../dataset/traindata-new.xlsx')
data_df
# Out:
#      uuid  Label Uniprot Target E3 ligase  PDB     Name  \
# 0       1      1  Q9NWZ3  IRAK4      CRBN  NaN      NaN
# 1       2      1  O15379  HDAC3       VHL  NaN   XZ9002
# 2       3      1  P11802   CDK4       VHL  NaN   CST651
# 3       4      1  Q00534   CDK6       VHL  NaN   CST651
# 4       5      1  O14965  AURKA      CRBN  NaN    JB170
# ..    ...    ...     ...    ...       ...  ...      ...
# 346   347      1  O60885   BRD4     FEM1B  NaN      NaN
# 347   348      0  O60885   BRD4     FEM1B  NaN      NaN
# 348   349      1  O60885   BRD4     FEM1B  NaN      NaN
# 349   350      1  P03372     ER      CRBN  NaN  ARV-471
# 350   351      1  P10275     AR      CRBN  NaN  ARV-110
#
#                                                 Smiles  DC50 (nM)  Dmax (%)  \
# 0    CC(C)NC1=CC(N2C=CC3=CC(C#N)=CN=C32)=NC=C1C(=O)...      405.0      90.0
# 1    CCCNNC(=O)C1=CC=C(C2=CC=C(NC(=O)CCCCCCC(=O)N[C...       42.0       NaN
# ...

# %%
temp_data_df = data_df[["Uniprot", "Target"]].drop_duplicates()
temp_data_df
# Out:
#     Uniprot  Target
# 0    Q9NWZ3   IRAK4
# 1    O15379   HDAC3
# 2    P11802    CDK4
# 3    Q00534    CDK6
# 4    O14965   AURKA
# ..      ...     ...
# 321  Q9BY41   HDAC8
# 322  P10415    BCL2
# 323  Q07817  BCL-xL
# 339  P10636     Tau
# 340  Q03111   MLLT1
#
# [65 rows x 2 columns]

# %%
import os
pdb_file_list = os.listdir('../dataset/protein_from_alphafold_database/')
pdb_file_list
# Out:
# ['SMARCA2.pdb',
#  'AURKA.pdb',
#  '._VHL.pdb',
#  'BTK.pdb',
#  'HDAC3.pdb',
#  'TYR.pdb',
#  'CDK4.pdb',
#  'CDK2.pdb',
#  'ALK.pdb',
#  'BTK C481G.pdb',
#  'CRBN.pdb',
#  'BRAF G469A.pdb',
#  'VHL.pdb',
#  'BTK C481T.pdb',
#  'ALK G1202R.pdb',
#  'AKT1.pdb',
#  'BCL2.pdb',
#  'HDAC1.pdb',
#  'EGFR del19-T790M-C797S.pdb',
#  'EGFR L858R-T790M.pdb',
#  'RIPK2.pdb',
#  'BRD2.pdb',
#  'HDAC6.pdb',
#  '._CRBN.pdb',
#  'MDM2.pdb',
#  'FAK.pdb',
#  'AR.pdb',
#  'FLT3-ITD.pdb',
#  'EGFR e19d.pdb',
#  'HDAC2.pdb',
#  'MLLT1.pdb',
#  'BCR-ABL T315I.pdb',
#  'GSK-3beta.pdb',
#  'BTK C481S.pdb',
#  'BCL-xL.pdb',
#  'CDK6.pdb',
#  'ER.pdb',
#  'BRD9.pdb',
#  'AR-V7.pdb',
#  'SMARCA4.pdb',
#  'AR T878A.pdb',
#  'IRAK1.pdb',
#  'HSP90.pdb',
#  'IRAK4.pdb',
#  'BRD4.pdb',
#  'FGFR1.pdb',
#  'JAK2 R683G.pdb',
#  'BRD3.pdb',
#  'SHP2.pdb',
#  'FGFR2.pdb',
#  'BRAF V600E.pdb',
#  'BTK C481A.pdb',
#  'SF3B1.pdb',
#  'PARP1.pdb',
#  'SOS1.pdb',
#  'AKT3.pdb',
#  'EGFR.pdb',
#  'WDR5.pdb',
# ...

# %%
for index, row in temp_data_df.iterrows():
    target, uniport = row["Target"], row["Uniprot"]
    if f"{target}.pdb" not in pdb_file_list:
        print(f"{target} - {uniport}")
# Out:
# EGFR L858R/T790M - P00533
# EGFR del19/T790M/C797S - P00533

# %%
data_df["Target"].sort_values().tolist()
# Out:
# ['AKT1',
#  'AKT1',
#  'AKT2',
#  'AKT2',
#  'AKT3',
#  'AKT3',
#  'ALK',
#  'ALK',
#  'ALK G1202R',
#  'AR',
#  'AR',
#  'AR',
#  'AR',
#  'AR',
#  'AR',
#  'AR',
#  'AR',
#  'AR',
#  'AR',
#  'AR',
#  'AR',
#  'AR',
#  'AR',
#  'AR',
#  'AR',
#  'AR',
#  'AR',
#  'AR',
#  'AR',
#  'AR',
#  'AR',
#  'AR',
#  'AR',
#  'AR',
#  'AR',
#  'AR',
#  'AR',
#  'AR',
#  'AR',
#  'AR',
#  'AR',
#  'AR',
#  'AR',
#  'AR',
#  'AR',
#  'AR',
#  'AR',
#  'AR',
#  'AR T878A',
#  'AR T878A',
#  'AR T878A',
#  'AR T878A',
#  'AR T878A',
#  'AR T878A',
#  'AR-V7',
#  'AR-V7',
#  'AR-V7',
#  'AURKA',
#  'BCL-xL',
#  'BCL-xL',
#  'BCL-xL',
#  'BCL-xL',
#  'BCL-xL',
#  'BCL-xL',
#  'BCL-xL',
#  'BCL-xL',
#  'BCL2',
#  'BCL2',
#  'BCL2',
#  'BCL2',
#  'BCL2',
#  'BCL2',
#  'BCL2',
#  'BCL2',
#  'BCR-ABL',
#  'BCR-ABL',
#  'BCR-ABL',
#  'BCR-ABL',
#  'BCR-ABL',
#  'BCR-ABL',
#  'BCR-ABL',
#  'BCR-ABL',
#  'BCR-ABL',
#  'BCR-ABL',
#  'BCR-ABL',
#  'BCR-ABL',
#  'BCR-ABL',
#  'BCR-ABL',
#  'BCR-ABL',
# ...
